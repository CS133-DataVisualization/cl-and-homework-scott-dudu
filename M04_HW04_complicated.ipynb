# %% [markdown]
# # Working with complicated dataset

# %% [markdown]
# Your name: Scott Du

# %% [markdown]
# ### Question 1
#
# blast_results: https://raw.githubusercontent.com/csbfx/advpy122-data/master/blast_results.csv
#
# Read in the data from the csv file above. Skip all the comment lines, create a header for the dataframe based on the fields list in the comment line that starts with **# Fields:**. Drop the first column `query acc.ver`. Set the `subject acc.ver` as the index of the dataframe. The last column of the dataframe should be `publications`. Show the first five rows of the resulting dataframe.

# %%
### Your code here . . .
import pandas as pd
import urllib.request

blast_results = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/blast_results.csv"

with urllib.request.urlopen(blast_results) as f:
  line = f.readline().decode("utf-8")
  while not line.startswith("\"# Fields:"):
    line = f.readline().decode("utf-8")
  columns = line.replace('"', '').replace(', ', ',').strip().split(",")[1:15]

blast = pd.read_csv(
    blast_results,
    header=0,
    names=columns,
    index_col=0,
    usecols=range(1, 15),
    comment="#",
    skiprows=1,
    na_values="-",
    thousands=','
)

blast.head(5)
# Out:
#                  % identity  alignment length  mismatches  gap opens  \
# subject acc.ver
# NP_904328.1         100.000               318           0          0
# AGK29621.1           99.686               318           1          0
# YP_220563.1          99.686               318           1          0
# ACM24502.1           99.686               318           1          0
# AHG32084.1           99.371               318           2          0
#
#                  q. start  q. end  s. start  s. end  evalue  bit score  \
# subject acc.ver
# NP_904328.1             1     318         1     318       0        629
# AGK29621.1              1     318         1     318       0        629
# YP_220563.1             1     318         1     318       0        627
# ACM24502.1              1     318         1     318       0        627
# AHG32084.1              1     318         1     318       0        627
#
#                  % positives  bonds  publications
# subject acc.ver
# ...

# %% [markdown]
# ### Question 2
# What is the average number of publications?

# %%
### Your code here . . .
print(blast.publications.mean())
# Out:
# 26.989690721649485

# %% [markdown]
# The average number of publications is 26.99 publications.

# %% [markdown]
# ### Question 3
# List the `subject acc.ver` that has over 15,000 bonds.

# %%
### Your code here . . .
blast[blast['bonds'] > 15000].index.tolist()
# Out:
# ['AGK29621.1',
#  'AHG32084.1',
#  '6G2J_H',
#  'YP_002791042.1',
#  'AGK29634.1',
#  '0806162F',
#  'YP_009112408.1',
#  'YP_001876469.1',
#  'YP_009092269.1',
#  'AHG32149.1',
#  'YP_009092074.1',
#  'YP_009450474.1',
#  'YP_004123270.1',
#  'YP_009092073.1',
#  'AHZ60901.1',
#  'YP_004123350.1',
#  'YP_009453754.1',
#  'ADD46492.1',
#  'YP_007025968.1',
#  'YP_009453806.1',
#  'YP_007024956.1',
#  'ASM92364.1',
#  'YP_006073044.1',
#  'ASM92494.1',
#  'ADG95699.1',
#  'YP_004891275.1',
#  'YP_009166014.1',
#  'YP_009538416.1',
#  'YP_009414182.1',
#  'YP_009178854.1',
#  'YP_009414415.1',
#  'YP_009353908.1',
#  'YP_009093743.1',
#  'ABX45285.1',
#  'YP_009414156.1',
#  'YP_009414363.1']

# %% [markdown]
# ['AGK29621.1',
#  'AHG32084.1',
#  '6G2J_H',
#  'YP_002791042.1',
#  'AGK29634.1',
#  '0806162F',
#  'YP_009112408.1',
#  'YP_001876469.1',
#  'YP_009092269.1',
#  'AHG32149.1',
#  'YP_009092074.1',
#  'YP_009450474.1',
#  'YP_004123270.1',
#  'YP_009092073.1',
#  'AHZ60901.1',
#  'YP_004123350.1',
#  'YP_009453754.1',
#  'ADD46492.1',
#  'YP_007025968.1',
#  'YP_009453806.1',
#  'YP_007024956.1',
#  'ASM92364.1',
#  'YP_006073044.1',
#  'ASM92494.1',
#  'ADG95699.1',
#  'YP_004891275.1',
#  'YP_009166014.1',
#  'YP_009538416.1',
#  'YP_009414182.1',
#  'YP_009178854.1',
#  'YP_009414415.1',
#  'YP_009353908.1',
#  'YP_009093743.1',
#  'ABX45285.1',
#  'YP_009414156.1',
#  'YP_009414363.1']

# %% [markdown]
# ### Question 4
# Create a plot that shows the correlation between `% identity` and `% positives`.

# %%
### Your code here . . .
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.lmplot(
    data=blast,
    x='% identity',
    y='% positives'
  )

plt.title("Relationship between % identity and % positives", pad=0.5)
# Out:
# Text(0.5, 1.0, 'Relationship between % identity and % positives')

# %% [markdown]
# ### Question  5
# Add a column `Protein source` to the dataframe from Question 1 based on the data in this csv file: https://raw.githubusercontent.com/csbfx/advpy122-data/master/protein_source.csv. Merge the data when the `subject acc.ver` from the dataframe equals to `Protein` in the csv file. Entries without a matching protein will have `NA` as `Protein source`.

# %%
### Your code here . . .
protein_source = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/protein_source.csv"
protein = pd.read_csv(protein_source)
protein.set_index('Protein', inplace=True)

blast['Protein source'] = protein['Source']
blast.fillna('NA', inplace=True)
blast.head(5)
# Out:
# /tmp/ipykernel_307/3452808579.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   blast.fillna('NA', inplace=True)
#                  % identity  alignment length  mismatches  gap opens  \
# subject acc.ver
# NP_904328.1         100.000               318           0          0
# AGK29621.1           99.686               318           1          0
# YP_220563.1          99.686               318           1          0
# ACM24502.1           99.686               318           1          0
# AHG32084.1           99.371               318           2          0
#
#                  q. start  q. end  s. start  s. end  evalue  bit score  \
# subject acc.ver
# NP_904328.1             1     318         1     318       0        629
# AGK29621.1              1     318         1     318       0        629
# ...
